# %%
import imaplib

# Set up the IMAP connection
imap_host = 'outlook.office365.com'
imap_port = '993'
imap = imaplib.IMAP4_SSL(imap_host, imap_port)

# Log in to the account
username = 'campuswireanswerbot@outlook.com'
password = 'group21cpwire'
imap.login(username, password)

# Select the mailbox you want to access (e.g., 'inbox', 'sent', 'drafts', etc.)
mailbox = 'inbox'
imap.select(mailbox)

# Search for emails in the selected mailbox
# Here, we are searching for all emails that match the given criteria
# You can modify the search criteria as per your requirement
search_criteria = 'ALL'
status, data = imap.search(None, search_criteria)

# Loop through the list of emails and fetch their details
for num in data[0].split():
    status, email_data = imap.fetch(num, '(RFC822)')
    print('Message %s\n%s\n' % (num, email_data[0][1]))

# Close the connection
imap.close()
imap.logout()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /var/folders/c6/7p813kjd7lq1zfvvc8yr1dq40000gp/T/ipykernel_66954/4241623419.py in <module>
#       9 username = 'campuswireanswerbot@outlook.com'
#      10 password = 'group21cpwire'
# ---> 11 imap.login(username, password)
#      12
#      13 # Select the mailbox you want to access (e.g., 'inbox', 'sent', 'drafts', etc.)
#
# ~/opt/anaconda3/lib/python3.9/imaplib.py in login(self, user, password)
#     610         typ, dat = self._simple_command('LOGIN', user, self._quote(password))
#     611         if typ != 'OK':
# --> 612             raise self.error(dat[-1])
#     613         self.state = 'AUTH'
#     614         return typ, dat
#
# error: b'LOGIN failed.'

# %%
# import the required libraries
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import pickle
import os.path
import base64
import email
from bs4 import BeautifulSoup
  
# Define the SCOPES. If modifying it, delete the token.pickle file.
SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']
  
def getEmails():
    # Variable creds will store the user access token.
    # If no valid token found, we will create one.
    creds = None
  
    # The file token.pickle contains the user access token.
    # Check if it exists
    if os.path.exists('token.pickle'):
  
        # Read the token from the file and store it in the variable creds
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
  
    # If credentials are not available or are invalid, ask the user to log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
  
        # Save the access token in token.pickle file for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
  
    # Connect to the Gmail API
    service = build('gmail', 'v1', credentials=creds)
  
    # request a list of all the messages
    result = service.users().messages().list(userId='me').execute()
  
    # We can also pass maxResults to get any number of emails. Like this:
    # result = service.users().messages().list(maxResults=200, userId='me').execute()
    messages = result.get('messages')
  
    # messages is a list of dictionaries where each dictionary contains a message id.
  
    # iterate through all the messages
    for msg in messages:
        # Get the message from its id
        txt = service.users().messages().get(userId='me', id=msg['id']).execute()
  
        # Use try-except to avoid any Errors
        try:
            # Get value of 'payload' from dictionary 'txt'
            payload = txt['payload']
            headers = payload['headers']
  
            # Look for Subject and Sender Email in the headers
            for d in headers:
                if d['name'] == 'Subject':
                    subject = d['value']
                if d['name'] == 'From':
                    sender = d['value']
  
            # The Body of the message is in Encrypted format. So, we have to decode it.
            # Get the data and decode it with base 64 decoder.
            parts = payload.get('parts')[0]
            data = parts['body']['data']
            data = data.replace("-","+").replace("_","/")
            decoded_data = base64.b64decode(data)
  
            # Now, the data obtained is in lxml. So, we will parse 
            # it with BeautifulSoup library
            soup = BeautifulSoup(decoded_data , "lxml")
            body = soup.body()
  
            # Printing the subject, sender's email and message
            print("Subject: ", subject)
            print("From: ", sender)
            print("Message: ", body)
            print('\n')
        except:
            pass
  
  
getEmails()
# Out:
# Subject:  Security alert
# From:  Google <no-reply@accounts.google.com>
# Message:  [<p>[image: Google]
# cp-answerbot was granted access to your Google Account
#
#
# campuswireanswerbot@gmail.com
#
# If you did not grant access, you should check this activity and secure your
# account.
# Check activity
# <https:>
# You can also see security activity at
# https://myaccount.google.com/notifications
# You received this email to let you know about important changes to your
# Google Account and services.
# Â© 2023 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA
# </https:></p>, <https:>
# You can also see security activity at
# https://myaccount.google.com/notifications
# You received this email to let you know about important changes to your
# Google Account and services.
# Â© 2023 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA
# </https:>]
#
#
# Subject:  Your project answerbot-382809 has been shut down
# From:  Platform Notifications <PlatformNotifications-noreply@google.com>
# Message:  [<p>Project Permanent Deletion Warning
#
#
# Dear Developer,
#
# Your Google Cloud project answerbot-382809 was shut down on April 05, 2023
# 9:50:40 AM UTC.
#
# Shut-down projects and the data stored in them may be recovered for a
# limited time before the projects are permanently deleted. If you'd like to
# recover your project, you must cancel the project's permanent deletion
# before May 05, 2023 9:50:40 AM UTC.
#
# To recover your shut-down project:
#
# Visit the Resources pending deletion page.
# Select the project you want to recover, and click Restore.
# In the confirmation dialog, click Restore.
#
#
# If you cannot recover your project by following the instructions above, you
# can try restoring it using the gcloud undelete command.
#
# If you take no action by May 05, 2023 9:50:40 AM UTC, you will be unable to
# recover your project.
#
# If you have any questions, please visit Google Cloud Platform Resource
# Manager Documentation or contact Google Cloud Platform Support.
#
# Cordially,
# The Google Cloud Platform Team
#
#
# Â© 2023 Google LLC. 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# You have received this mandatory email service announcement to update you
# about important changes to your Google project, product or account.
#
#
# </p>]
#
#
# Subject:  Take the next step by customizing your Google Account
# From:  Google Community Team <googlecommunityteam-noreply@google.com>
# Message:  [<p>Let's get started!
#
# Welcome to Google. Your new account comes with access to Google products,
# apps, and services. Here are a few tips to get you started.
#
# Personalize your communication and account settings
#
# Get the most out of your Google Account
#
# We'll send you personalized tips, news, and recommendations from Google.
#
# Yes, keep me
# updated<https:>
#
# Get personalized tips, news, and recommendations for Google products and
# services<https:>
#
# Customize your privacy and security
# settings<https:>
#
# Confirm your options are right for you
#
# Review and change your privacy and security options to make Google work
# better for you.
#
# Confirm<https:>
#
# Get started with products and apps included with your account
#
# Stay in the know with the Google app
#
# Find quick answers, explore your interests, and stay up to date.
#
# Try
# it<https:>
#
# Try the Google app to find answers and information
# quickly<https:>
#
# Explore apps to use Google products and services across
# devices<https:>
#
# More from Google
#
# Discover the latest apps from Google.
#
# For
# Android<https:>
#
# For
# iOS<https:>
#
# Replies to this email aren't monitored. If you have a question about your
# new account, the Help
# Center<https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:></https:></https:></https:></https:></https:></https:></https:></https:></https:></p>, <https:>
#
# Get personalized tips, news, and recommendations for Google products and
# services<https:>
#
# Customize your privacy and security
# settings<https:>
#
# Confirm your options are right for you
#
# Review and change your privacy and security options to make Google work
# better for you.
#
# Confirm<https:>
#
# Get started with products and apps included with your account
#
# Stay in the know with the Google app
#
# Find quick answers, explore your interests, and stay up to date.
#
# Try
# it<https:>
#
# Try the Google app to find answers and information
# quickly<https:>
#
# Explore apps to use Google products and services across
# devices<https:>
#
# More from Google
#
# Discover the latest apps from Google.
#
# For
# Android<https:>
#
# For
# iOS<https:>
#
# Replies to this email aren't monitored. If you have a question about your
# new account, the Help
# Center<https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:></https:></https:></https:></https:></https:></https:></https:></https:></https:>, <https:>
#
# Customize your privacy and security
# settings<https:>
#
# Confirm your options are right for you
#
# Review and change your privacy and security options to make Google work
# better for you.
#
# Confirm<https:>
#
# Get started with products and apps included with your account
#
# Stay in the know with the Google app
#
# Find quick answers, explore your interests, and stay up to date.
#
# Try
# it<https:>
#
# Try the Google app to find answers and information
# quickly<https:>
#
# Explore apps to use Google products and services across
# devices<https:>
#
# More from Google
#
# Discover the latest apps from Google.
#
# For
# Android<https:>
#
# For
# iOS<https:>
#
# Replies to this email aren't monitored. If you have a question about your
# new account, the Help
# Center<https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:></https:></https:></https:></https:></https:></https:></https:></https:>, <https:>
#
# Confirm your options are right for you
#
# Review and change your privacy and security options to make Google work
# better for you.
#
# Confirm<https:>
#
# Get started with products and apps included with your account
#
# Stay in the know with the Google app
#
# Find quick answers, explore your interests, and stay up to date.
#
# Try
# it<https:>
#
# Try the Google app to find answers and information
# quickly<https:>
#
# Explore apps to use Google products and services across
# devices<https:>
#
# More from Google
#
# Discover the latest apps from Google.
#
# For
# Android<https:>
#
# For
# iOS<https:>
#
# Replies to this email aren't monitored. If you have a question about your
# new account, the Help
# Center<https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:></https:></https:></https:></https:></https:></https:></https:>, <https:>
#
# Get started with products and apps included with your account
#
# Stay in the know with the Google app
#
# Find quick answers, explore your interests, and stay up to date.
#
# Try
# it<https:>
#
# Try the Google app to find answers and information
# quickly<https:>
#
# Explore apps to use Google products and services across
# devices<https:>
#
# More from Google
#
# Discover the latest apps from Google.
#
# For
# Android<https:>
#
# For
# iOS<https:>
#
# Replies to this email aren't monitored. If you have a question about your
# new account, the Help
# Center<https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:></https:></https:></https:></https:></https:></https:>, <https:>
#
# Try the Google app to find answers and information
# quickly<https:>
#
# Explore apps to use Google products and services across
# devices<https:>
#
# More from Google
#
# Discover the latest apps from Google.
#
# For
# Android<https:>
#
# For
# iOS<https:>
#
# Replies to this email aren't monitored. If you have a question about your
# new account, the Help
# Center<https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:></https:></https:></https:></https:></https:>, <https:>
#
# Explore apps to use Google products and services across
# devices<https:>
#
# More from Google
#
# Discover the latest apps from Google.
#
# For
# Android<https:>
#
# For
# iOS<https:>
#
# Replies to this email aren't monitored. If you have a question about your
# new account, the Help
# Center<https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:></https:></https:></https:></https:>, <https:>
#
# More from Google
#
# Discover the latest apps from Google.
#
# For
# Android<https:>
#
# For
# iOS<https:>
#
# Replies to this email aren't monitored. If you have a question about your
# new account, the Help
# Center<https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:></https:></https:></https:>, <https:>
#
# For
# iOS<https:>
#
# Replies to this email aren't monitored. If you have a question about your
# new account, the Help
# Center<https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:></https:></https:>, <https:>
#
# Replies to this email aren't monitored. If you have a question about your
# new account, the Help
# Center<https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:></https:>, <https:>
# likely has the answer you're looking for.
#
# Google LLC 1600 Amphitheatre Parkway, Mountain View, CA 94043
#
# This email was sent to you because you created a Google Account.
# </https:>]
