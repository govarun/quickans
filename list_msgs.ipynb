# %%
import asyncio
import configparser
from graph import Graph

message_page = None
async def main():
    print('Python Graph Tutorial\n')

    # Load settings
    config = configparser.ConfigParser()
    config.read(['config.cfg', 'config.dev.cfg'])
    azure_settings = config['azure']

    graph: Graph = Graph(azure_settings)
    await list_inbox(graph)

#     while choice != 0:
#         print('Please choose one of the following options:')
#         print('0. Exit')
#         print('1. Display access token')
#         print('2. List my inbox')
#         print('3. Send mail')
#         print('4. Make a Graph call')

#         try:
#             choice = int(input())
#         except ValueError:
#             choice = -1

#         if choice == 0:
#             print('Goodbye...')
#         elif choice == 1:
#             await display_access_token(graph)
#         elif choice == 2:
#             await list_inbox(graph)
#         elif choice == 3:
#             await send_mail(graph)
#         elif choice == 4:
#             await make_graph_call(graph)
#         else:
#             print('Invalid choice!\n')


async def greet_user(graph: Graph):
    user = await graph.get_user()
    if user is not None:
        print('Hello,', user.display_name)
        # For Work/school accounts, email is in mail property
        # Personal accounts, email is in userPrincipalName
        print('Email:', user.mail or user.user_principal_name, '\n')

async def display_access_token(graph: Graph):
    token = await graph.get_user_token()
    print('User token:', token, '\n')

async def list_inbox(graph: Graph):
    global message_page
    message_page = await graph.get_inbox()
    if message_page is not None and message_page.value is not None:
        # Output each message's details
        
        for message in message_page.value:
            print(type(message))
            print("Body:", message.body_preview)
            print('Message:', message.subject)
            if (
                message.from_ is not None and
                message.from_.email_address is not None
            ):
                print('  From:', message.from_.email_address.name or 'NONE')
                print('  From email:', message.from_.email_address.address or 'NONE')
            else:
                print('  From: NONE')
            print('  Status:', 'Read' if message.is_read else 'Unread')
            print('  Received:', message.received_date_time)

        # If @odata.nextLink is present
        more_available = message_page.odata_next_link is not None
        print('\nMore messages available?', more_available, '\n')

async def send_mail(graph: Graph, subject, content, email):
    # Send mail to the signed-in user
    # Get the user for their email address
    user = await graph.get_user()
    if user is not None:
        user_email = user.mail or user.user_principal_name
        await graph.send_mail(subject, content, email)
#         await graph.send_mail('Testing Microsoft Graph', 'Hello world!', "ssehgal4@illinois.edu" or '')
        print('Mail sent.\n')

async def make_graph_call(graph: Graph):
    # TODO
    return


# Run main
# asyncio.run(main())

# async def main():
#     print(1)
    
await main()
# Out:
# Python Graph Tutorial
#
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code FMZBGYSGY to authenticate.
# <class 'msgraph.generated.models.message.Message'>
# Body: Hi everyone, As per the posts #749 and #719, we have addressed all your regrade requests on gradescope and also regraded 4.3 to award marks accordingly. Please check these and if you still require a regrade/demo, please fill in the appropriate regrade req
# Message: Eashan Gupta: MP1 Demo slots
#   From: Campuswire Team
#   From email: team@campuswiremail.com
#   Status: Read
#   Received: 2023-04-17 06:22:14+00:00
# <class 'msgraph.generated.models.message.Message'>
# Body: Does anyone know how to do the assessment of proposal? I do not see any option do that on Moodle.
#
#
# Han Li asked a question in Advanced Information Retrieval
#         Han Li
# April 16, 9:56 PM EST
#
# Assessment of proposal
#
# Does anyone know how to do
# Message: Han Li: Assessment of proposal
#   From: Campuswire Team
#   From email: team@campuswiremail.com
#   Status: Read
#   Received: 2023-04-17 01:58:06+00:00
# <class 'msgraph.generated.models.message.Message'>
# Body: Sarthak Moorjani:
#
# To ensure atomicity of the transaction (either all operations happen or nothing happens), we must delete the account too. So a balance on the account should return a does not exist error.
#
# Nice test case :)
#
#
# New answer in #779:
# Message: New answer in #779: Doubt related to account creation in deposit, followed by abort
#   From: Campuswire Team
#   From email: team@campuswiremail.com
#   Status: Read
#   Received: 2023-04-17 01:51:58+00:00
# <class 'msgraph.generated.models.message.Message'>
# Body: Hassam Uddin:
#
# Yes, you should roll back the account creation if T1 gets aborted. There might be a simpler way to determine whether an account was created during a transaction than keeping a map, but that’s an implementation decision.
#
# It is up to you
# Message: New answer in #779: Doubt related to account creation in deposit, followed by abort
#   From: Campuswire Team
#   From email: team@campuswiremail.com
#   Status: Read
#   Received: 2023-04-16 23:46:32+00:00
# <class 'msgraph.generated.models.message.Message'>
# Body: Anonymous:
#
# I think if the account was created before that transaction T1, then account A would still exist and BALANCE A would succeed. If account A was created within T1 then once it is rolled back I think account A would not exist anymore.
#
#
# New a
# Message: New answer in #779: Doubt related to account creation in deposit, followed by abort
#   From: Campuswire Team
#   From email: team@campuswiremail.com
#   Status: Read
#   Received: 2023-04-16 23:44:29+00:00
# <class 'msgraph.generated.models.message.Message'>
# Body: I am not really sure what the problem is and I really need a detailed solution for this.
#
#
# Yichen Li asked a question in Intro Computing: Non-Tech
#         Yichen Li
# April 16, 5:42 PM EST
#
# Practice Exam 3 Question 24
#
#  I am not really sure what th
# Message: Yichen Li: Practice Exam 3 Question 24
#   From: Campuswire Team
#   From email: team@campuswiremail.com
#   Status: Unread
#   Received: 2023-04-16 21:45:44+00:00
# <class 'msgraph.generated.models.message.Message'>
# Body: Good afternoon, As of right now my exam is scheduled for 11 am on Monday. I was a little bit late to signing up for the exam as there is usually plenty of spots open when I normally sign up. In prairie test I can not check to see if there are any open spo
# Message: Reid Butterly: Wondering if it is possible to schedule later exam time on monday?
#   From: Campuswire Team
#   From email: team@campuswiremail.com
#   Status: Read
#   Received: 2023-04-16 21:21:50+00:00
# <class 'msgraph.generated.models.message.Message'>
# Body: Yelin Zhong asked a question in Intro Computing: Non-Tech
#         Yelin Zhong
# April 16, 4:52 PM EST
#
# Why I am wrong? Thank you!
#
#
#
# View question on Campuswire
#
# You are receiving this email because you are a registered member of Campuswire.
# To u
# Message: Yelin Zhong: Why I am wrong? Thank you!
#   From: Campuswire Team
#   From email: team@campuswiremail.com
#   Status: Read
#   Received: 2023-04-16 20:52:55+00:00
# <class 'msgraph.generated.models.message.Message'>
# Body: I emailed my TA and Mrs. Lewis earlier today as well as filling out the exam extension request form. I have been pretty sick all weekend, but this morning I woke up with a pretty strong fever and I have been over the toilet most of the day. I never got an
# Message: Holden Quinn: Exam Extension
#   From: Campuswire Team
#   From email: team@campuswiremail.com
#   Status: Read
#   Received: 2023-04-16 20:36:20+00:00
# <class 'msgraph.generated.models.message.Message'>
# Body: I am not sure how to only get the strings before an empty string. I would appreciate some help.
#
#
# Anonymous asked a question in Intro Computing: Non-Tech
#         Anonymous
# April 16, 4:08 PM EST
#
# PE 25
#
#   I am not sure how to only get the strings
# Message: Anonymous: PE 25
#   From: Campuswire Team
#   From email: team@campuswiremail.com
#   Status: Read
#   Received: 2023-04-16 20:09:25+00:00
#
# More messages available? True

# %%
# !pip install openai

# %%
from bs4 import BeautifulSoup

for msg in message_page.value:
    bodyContent = msg._body._content
    print(msg._id)
#     print(bodyContent)
#     parsed_html = BeautifulSoup(bodyContent)
#     heading = parsed_html.find("h1")
    
#     print(heading.text)
# Out:
# AAMkADVjNTU3YWM4LTZmZDYtNDllZS04YjI1LTYzMDllZWJiOWU5YQBGAAAAAADcM3LdSMaBQoKH1Fywi5UuBwCVErZPuEQLT4F1djQHF7RcAAAAAAEMAACVErZPuEQLT4F1djQHF7RcAADvI3sfAAA=
# AAMkADVjNTU3YWM4LTZmZDYtNDllZS04YjI1LTYzMDllZWJiOWU5YQBGAAAAAADcM3LdSMaBQoKH1Fywi5UuBwCVErZPuEQLT4F1djQHF7RcAAAAAAEMAACVErZPuEQLT4F1djQHF7RcAADvI3sdAAA=
# AAMkADVjNTU3YWM4LTZmZDYtNDllZS04YjI1LTYzMDllZWJiOWU5YQBGAAAAAADcM3LdSMaBQoKH1Fywi5UuBwCVErZPuEQLT4F1djQHF7RcAAAAAAEMAACVErZPuEQLT4F1djQHF7RcAADvI3scAAA=
# AAMkADVjNTU3YWM4LTZmZDYtNDllZS04YjI1LTYzMDllZWJiOWU5YQBGAAAAAADcM3LdSMaBQoKH1Fywi5UuBwCVErZPuEQLT4F1djQHF7RcAAAAAAEMAACVErZPuEQLT4F1djQHF7RcAADvI3sbAAA=
# AAMkADVjNTU3YWM4LTZmZDYtNDllZS04YjI1LTYzMDllZWJiOWU5YQBGAAAAAADcM3LdSMaBQoKH1Fywi5UuBwCVErZPuEQLT4F1djQHF7RcAAAAAAEMAACVErZPuEQLT4F1djQHF7RcAADvI3saAAA=
# AAMkADVjNTU3YWM4LTZmZDYtNDllZS04YjI1LTYzMDllZWJiOWU5YQBGAAAAAADcM3LdSMaBQoKH1Fywi5UuBwCVErZPuEQLT4F1djQHF7RcAAAAAAEMAACVErZPuEQLT4F1djQHF7RcAADvI3sYAAA=
# AAMkADVjNTU3YWM4LTZmZDYtNDllZS04YjI1LTYzMDllZWJiOWU5YQBGAAAAAADcM3LdSMaBQoKH1Fywi5UuBwCVErZPuEQLT4F1djQHF7RcAAAAAAEMAACVErZPuEQLT4F1djQHF7RcAADvI3sXAAA=
# AAMkADVjNTU3YWM4LTZmZDYtNDllZS04YjI1LTYzMDllZWJiOWU5YQBGAAAAAADcM3LdSMaBQoKH1Fywi5UuBwCVErZPuEQLT4F1djQHF7RcAAAAAAEMAACVErZPuEQLT4F1djQHF7RcAADvI3sWAAA=
# AAMkADVjNTU3YWM4LTZmZDYtNDllZS04YjI1LTYzMDllZWJiOWU5YQBGAAAAAADcM3LdSMaBQoKH1Fywi5UuBwCVErZPuEQLT4F1djQHF7RcAAAAAAEMAACVErZPuEQLT4F1djQHF7RcAADvI3sVAAA=
# AAMkADVjNTU3YWM4LTZmZDYtNDllZS04YjI1LTYzMDllZWJiOWU5YQBGAAAAAADcM3LdSMaBQoKH1Fywi5UuBwCVErZPuEQLT4F1djQHF7RcAAAAAAEMAACVErZPuEQLT4F1djQHF7RcAADvI3sUAAA=

# %%
import os
import openai
from keys import *
from bs4 import BeautifulSoup
import time
openai.api_key = OPENAI_API_KEY

# %%
for msg in message_page.value:
    bodyContent = msg._body._content
    parsed_html = BeautifulSoup(bodyContent)
    
    start = parsed_html.find("p", attrs={'class':'markdown_tester'})
    
    preface = f"I am a teaching assistant and a student in my course has posed the following question. What is the answer? Question: "
    question = f"{start.text}\n"
    for tr in start.find_next_siblings("p"):
        question += tr.text
        images = tr.find_all("img")
        if images:
            question += images[0].attrs['src'] + "\n"
    
    completion = openai.ChatCompletion.create(
      model="gpt-3.5-turbo",
#     model="text-curie-001",
      messages=[
        {"role": "user", "content": preface + question}
      ]
    )

    print(f"Question Posed\n{question}")

    print("Model Answer\n")
    print(completion.choices[0].message.content)    
    print("\n\nQuestion-Answer Completed\n")
    time.sleep(20)
